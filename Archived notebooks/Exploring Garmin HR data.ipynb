# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from scipy.stats import norm
import math
import sidetable

# %%
survey = pd.read_csv("./surveydata.csv")
#how many observations
print(survey.SubjectID.count())
#unique ID
print(len(pd.unique(survey['SubjectID'])))
#unique description, 5 questions
print(pd.unique(survey['description']))
#print(max(survey['Unnamed:0']))
survey.head()
# Out:
# 5540
# 37
# ['Numeric answer for number of hours of sleep for participant on night before the run'
#  'Approximate time of day when run was performed'
#  'Type of surface (soft, hard, etc) for route that participant ran'
#  'General descriptions of running surface conditions (dry, wet, icy, etc)'
#  'RPE scale 1-10 of workout difficulty']
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                          description  \
# 0  Numeric answer for number of hours of sleep fo...
# 1     Approximate time of day when run was performed
# 2  Type of surface (soft, hard, etc) for route th...
# 3  General descriptions of running surface condit...
# 4               RPE scale 1-10 of workout difficulty
#
#                      filename  \
# 0  58_20180811_surveydata.csv
# 1  58_20180811_surveydata.csv
# 2  58_20180811_surveydata.csv
# 3  58_20180811_surveydata.csv
# 4  58_20180811_surveydata.csv
#
#                                                name  numerical_ans  \
# 0  MT Run Follow Up - Previous Nights Sleep (hours)            NaN
# 1                    MT Run Follow Up - Time of Run            NaN
# 2                        MT Run Follow Up - Surface            NaN
# 3             MT Run Follow Up - Surface Conditions            NaN
# 4           MT Run Follow Up - How Was Your Workout            NaN
#
#                 textual_ans  SubjectID  Year  Date      DataSource
# 0                       7.5         58  2018   811  surveydata.csv
# 1                8:03:00 AM         58  2018   811  surveydata.csv
# 2  Hard (sidewalk, asphalt)         58  2018   811  surveydata.csv
# 3                       Dry         58  2018   811  surveydata.csv
# 4              3 - Moderate         58  2018   811  surveydata.csv

# %%
df = survey[survey.description == 'Numeric answer for number of hours of sleep for participant on night before the run']
print(pd.unique(df['numerical_ans']))
print(pd.unique(df['textual_ans']))
# Out:
# [      nan  7.5       6.        7.25      6.5       7.        0.270833
#   5.        0.229167 18.        8.        9.5       5.5       5.75
#   8.5       4.        6.25      0.173611]
# ['7.5' '8' '7.50' '6.5' '7.00' '6' '7' '5' '6.5 hours' nan
#  '7.5 hrs, good sleep !' '9.00' '6.50' '8.50' '8 hours 45 minutes'
#  '6hours 41 minutes' '8 hours 20 minutes' '7 hours 13 minutes' '6 hours'
#  '7 hours 21 minutes' '6:40' '5.5' '0.313888889' '7 hours, 56 minutes'
#  '9 hours' '7 hours' '7 hours 50 minutes' '7 hours 15 minutes' '7.30'
#  '6 hours 39 minutes' '6 hours 10 minutes' '6 hours 16 minutes'
#  '8 hours 51 mnutes' '6 hours 48 minutes' '7 hours 12 minutes'
#  '7 hours 49 minutes' '6 hours 13 minutes' '8 hours 30 minutes'
#  '5hours 32minutes' '6 hours 34 minutes' '3' '8 hours' '0.243055556'
#  '5 hours 57 minutes' '7 hours 43 minutes' '5 hrs 56 minutes' '7.75'
#  '7hours 10minutes' '5.75' '7 hours 20 minutes' '5.67'
#  '6 hours 23 minutes' '6 hours 7 minutes' '7.25' '6.25' '4.00' '6.00'
#  '6 hours 49 minutes' '0.261111111' '6hours 53 minutes'
#  '7 hours 30 minutes' '8.00' '6 hours 40 minutes' '8 hours 35 minutes'
#  '6 hours 20 minutes' '6 hours 21 minutes' '6hours 36 minutes' '5.00'
#  '5.50' '6;30' '2.50' '0.364583333' '0.354861111' '6 hours 23 minutes '
#  '0.302083333' '8.5' '0.3125' '2.00' '9 hrs' '8 hrs' '9hrs' '8hrs'
#  '8.5hours' '4 hours' '7hours' '4hours' '6hours' '8.5hr' '8.5 hours'
#  '3hrs' '9' '3.50' '1.50' '4.75' '4.50' '10.00' '5.25' '0.00' '0' '4'
#  '8.0 (I did not sleep well at all)' '8.0 (poor sleep)' '7.5 and not well'
#  '7.0 (bad sleep; nightmares)' '7.5 not good' '7.0 + 20 min nap'
#  '8.0 but really poor sleep' '8.5 (I have some catching up to do!)'
#  '7.5 (and I did not sleep well)' '8.0 but it was not a good sleep'
#  "Don't remember" '6.75 and bad sleep' '7.0 (with some hot flashes)'
#  '7.5-8' '8.0, but I woke up several times'
#  '8 hours+ (I was really tired)' '6.30' '6.75' '6.74' '4.60' '5.33'
#  '6 hours 52 min' '5.10' '5 hours' '5 hours 8 min' '6 hours 17 min'
#  '4 hours 37 min' '6.60' '8.75' 'not enough 6ish'
#  '6.5 (solid, but not enough)' 'not enough...5.5' '8.5hrs!!'
#  'not enough....7' '6hrs' '7 ish' '7.5hrs' '7.40' 'unsure' 'unknown'
#  'Unknown' 'Unsure' 'Not sure' 'not sure' '11.8' '10' '11'
#  '7 hours 40 minutes' '8.4' '6.7' '4.25' '9.70' '4hrs 30min'
#  '5hrs 44 mins' '7hr 36mins' '5hr 30 min']

# %%
#Lets clean this data

#Drop 2 first columns
survey.drop(survey.columns[[0, 1]], axis=1, inplace=True)

# %%
#Create key variables

#For a unique survey, we can make a key variable concatenating  (SubjectID, Year and Date)
cols = ['SubjectID', 'Year', 'Date'] #This key variable might help to find same observation in the garmin database
survey['key'] = survey[cols].apply(lambda row: '_'.join(row.values.astype(str)), axis=1)

#For a unique observation in the survey, we can make a key2 with (SubjectID, Year, Date and description)
cols2 = ['SubjectID', 'Year', 'Date','description']
survey['key2'] = survey[cols2].apply(lambda row: '_'.join(row.values.astype(str)), axis=1)

#Count how many possible mistakes, duplicate observations may have
print(survey[survey.duplicated(subset=['key2'],keep=False)].SubjectID.count())
#53 from 5540 obs is not bad

#Lets just look to the first one
key_look = '424_2017_617'
survey[survey.key == key_look]
# Out:
# 53
#                                            description  \
# 462  Numeric answer for number of hours of sleep fo...
# 463     Approximate time of day when run was performed
# 464  Type of surface (soft, hard, etc) for route th...
# 465  General descriptions of running surface condit...
# 466  Numeric answer for number of hours of sleep fo...
# 467     Approximate time of day when run was performed
#
#                         filename  \
# 462  424_20170617_surveydata.csv
# 463  424_20170617_surveydata.csv
# 464  424_20170617_surveydata.csv
# 465  424_20170617_surveydata.csv
# 466  424_20170617_surveydata.csv
# 467  424_20170617_surveydata.csv
#
#                                                  name  numerical_ans  \
# 462  MT Run Follow Up - Previous Nights Sleep (hours)            6.0
# 463                    MT Run Follow Up - Time of Run            NaN
# 464                        MT Run Follow Up - Surface            NaN
# 465             MT Run Follow Up - Surface Conditions            NaN
# 466  MT Run Follow Up - Previous Nights Sleep (hours)            NaN
# 467                    MT Run Follow Up - Time of Run            NaN
#
#                   textual_ans  SubjectID  Year  Date      DataSource  \
# 462                       NaN        424  2017   617  surveydata.csv
# 463              '8:00:00 AM'        424  2017   617  surveydata.csv
# 464  Hard (sidewalk, asphalt)        424  2017   617  surveydata.csv
# 465                       Dry        424  2017   617  surveydata.csv
# 466                      6.00        424  2017   617  surveydata.csv
# 467                8:04:00 AM        424  2017   617  surveydata.csv
#
#               key                                               key2
# 462  424_2017_617  424_2017_617_Numeric answer for number of hour...
# 463  424_2017_617  424_2017_617_Approximate time of day when run ...
# 464  424_2017_617  424_2017_617_Type of surface (soft, hard, etc)...
# 465  424_2017_617  424_2017_617_General descriptions of running s...
# 466  424_2017_617  424_2017_617_Numeric answer for number of hour...
# 467  424_2017_617  424_2017_617_Approximate time of day when run ...

# %%
for col in survey.columns:
    pct_missing = np.mean(survey[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# description - 0%
# filename - 0%
# name - 0%
# numerical_ans - 98%
# textual_ans - 2%
# SubjectID - 0%
# Year - 0%
# Date - 0%
# DataSource - 0%
# key - 0%
# key2 - 0%

# %%
garmin = pd.read_csv("./garmindata.csv")

#how many observations
print(garmin.SubjectID.count())
#unique ID
print(len(pd.unique(garmin['SubjectID'])))

garmin.head()
# Out:
# 6412029
# 38
#    Unnamed: 0  Unnamed: 0.1                    filename  record.altitude[m]  \
# 0           5             5  58_20180916_garmindata.csv              1117.2
# 1           6             6  58_20180916_garmindata.csv              1116.4
# 2           7             7  58_20180916_garmindata.csv              1116.2
# 3           8             8  58_20180916_garmindata.csv              1116.2
# 4           9             9  58_20180916_garmindata.csv              1116.0
#
#    record.distance[m]  record.heart_rate[bpm]  \
# 0                3.17                    78.0
# 1                7.93                    78.0
# 2               10.39                    82.0
# 3               12.91                    86.0
# 4               15.66                    86.0
#
#    record.position_lat[semicircles]  record.position_long[semicircles]  \
# 0                       609492677.0                      -1.361950e+09
# 1                       609493159.0                      -1.361951e+09
# 2                       609493416.0                      -1.361951e+09
# 3                       609493682.0                      -1.361951e+09
# 4                       609493973.0                      -1.361951e+09
#
#    record.speed[m/s]  record.timestamp[s]  SubjectID  Year  Date  \
# 0              1.465                  0.0         58  2018   916
# 1              2.305                  2.0         58  2018   916
# 2              2.454                  3.0         58  2018   916
# 3              2.463                  4.0         58  2018   916
# 4              2.547                  5.0         58  2018   916
#
#        DataSource
# 0  garmindata.csv
# 1  garmindata.csv
# 2  garmindata.csv
# 3  garmindata.csv
# 4  garmindata.csv

# %%
#Lets explore this data

#Drop 2 first columns
garmin.drop(garmin.columns[[0, 1]], axis=1, inplace=True)

# %%
#Create key variables

#For a unique observation, we can make a key variable concatenating  (SubjectID, Year and Date)
cols = ['SubjectID', 'Year', 'Date'] #This key variable might help to find same observation in the survey database
garmin['key'] = garmin[cols].apply(lambda row: '_'.join(row.values.astype(str)), axis=1)

#unique ID
print(len(pd.unique(garmin['key'])))
#average observations per runner
print(len(pd.unique(garmin['key']))/37)
#data per observation
garmin.groupby('key')['SubjectID'].count()
# Out:
# 1657
# 44.78378378378378
# key
# 1942_2017_1008    15052
# 1942_2017_621      2455
# 1942_2017_624      3926
# 1942_2017_706      5375
# 1942_2017_708      7214
#                   ...
# 58_2018_910         773
# 58_2018_913         667
# 58_2018_915         779
# 58_2018_916         886
# 58_2018_924         549
# Name: SubjectID, Length: 1657, dtype: int64

# %%
#average data per observation
sum(garmin.groupby('key')['SubjectID'].count())/len(garmin.groupby('key')['SubjectID'].count())
# Out:
# 3869.661436330718

# %%
#Lets just look to the same day as the one looked for survey
key_look = '424_2017_617'
df = garmin[garmin.key == key_look]
#Sorting data by record.timestamp[s]
df.sort_values(by=['record.timestamp[s]'])
# Out:
#                            filename  record.altitude[m]  record.distance[m]  \
# 276286  424_20170617_garmindata.csv              1215.6                4.79
# 276287  424_20170617_garmindata.csv              1215.4                7.29
# 276288  424_20170617_garmindata.csv              1215.2                9.94
# 276289  424_20170617_garmindata.csv              1215.4               12.48
# 276290  424_20170617_garmindata.csv              1215.4               15.09
# ...                             ...                 ...                 ...
# 281298  424_20170617_garmindata.csv              1049.8            10431.47
# 281299  424_20170617_garmindata.csv              1049.8            10431.47
# 281300  424_20170617_garmindata.csv              1049.8            10431.47
# 281301  424_20170617_garmindata.csv              1049.8            10431.47
# 281302  424_20170617_garmindata.csv              1049.8            10431.60
#
#         record.heart_rate[bpm]  record.position_lat[semicircles]  \
# 276286                   124.0                       608901780.0
# 276287                   123.0                       608901725.0
# 276288                   123.0                       608901676.0
# 276289                   123.0                       608901629.0
# 276290                   122.0                       608901543.0
# ...                        ...                               ...
# 281298                   111.0                       609000034.0
# 281299                   113.0                       609000019.0
# 281300                   112.0                       608999998.0
# 281301                   111.0                       609000000.0
# 281302                   109.0                       609000014.0
#
#         record.position_long[semicircles]  record.speed[m/s]  \
# 276286                      -1.362250e+09              2.342
# 276287                      -1.362250e+09              2.342
# 276288                      -1.362250e+09              2.342
# 276289                      -1.362249e+09              2.482
# 276290                      -1.362249e+09              2.575
# ...                                   ...                ...
# 281298                      -1.360770e+09              0.177
# 281299                      -1.360770e+09              0.177
# 281300                      -1.360770e+09              0.168
# 281301                      -1.360770e+09              0.168
# 281302                      -1.360770e+09              0.168
#
#         record.timestamp[s]  SubjectID  Year  Date      DataSource  \
# 276286                  0.0        424  2017   617  garmindata.csv
# 276287                  1.0        424  2017   617  garmindata.csv
# 276288                  2.0        424  2017   617  garmindata.csv
# 276289                  3.0        424  2017   617  garmindata.csv
# 276290                  4.0        424  2017   617  garmindata.csv
# ...                     ...        ...   ...   ...             ...
# 281298               5078.0        424  2017   617  garmindata.csv
# 281299               5079.0        424  2017   617  garmindata.csv
# 281300               5080.0        424  2017   617  garmindata.csv
# 281301               5081.0        424  2017   617  garmindata.csv
# 281302               5082.0        424  2017   617  garmindata.csv
#
#                  key
# 276286  424_2017_617
# 276287  424_2017_617
# 276288  424_2017_617
# 276289  424_2017_617
# 276290  424_2017_617
# ...              ...
# 281298  424_2017_617
# 281299  424_2017_617
# 281300  424_2017_617
# 281301  424_2017_617
# 281302  424_2017_617
#
# [5017 rows x 13 columns]

# %%
#Lets plot the heart rate over all the running
plt.plot(df['record.timestamp[s]'], df['record.heart_rate[bpm]'])

# %%
#Lets plot the speed over all the running
plt.plot(df['record.timestamp[s]'], df['record.speed[m/s]'])

# %%
#Lets plot the heart rate vs. speed 
plt.scatter(df['record.heart_rate[bpm]'], df['record.speed[m/s]'])
